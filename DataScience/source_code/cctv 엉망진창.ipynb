# %%
import pandas as pd

# %%
CCTV_seoul = pd.read_csv("../data/01. CCTV_in_Seoul.csv",encoding = 'UTF-8')  #..은 "나와서"라는 의미

# %%
CCTV_seoul.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
CCTV_seoul.columns
# Out:
# Index(['기관명', '소계', '2013년도 이전', '2014년', '2015년', '2016년'], dtype='object')

# %%
CCTV_seoul.rename(columns={CCTV_seoul.columns[0]:'구별'}, inplace = True)

# %%
CCTV_seoul.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
pop_Seoul = pd.read_csv('../data/01. CCTV_in_Seoul.csv', 
                          header = 2,
                          usecols = 'B,D,G,J,N',
                          encoding = 'utf-8')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-43c2e6fb5e41> in <module>()
#       2                           header = 2,
#       3                           usecols = 'B,D,G,J,N',
# ----> 4                           encoding = 'utf-8')
#
# ...

# %%
CCTV_seoul.sort_values(by = '소계', ascending = False).head() #오름차순 정렬
# Out:
#      구별    소계  2013년도 이전  2014년  2015년  2016년
# 0   강남구  2780       1292    430    584    932
# 18  양천구  2034       1843    142     30    467
# 14  서초구  1930       1406    157    336    398
# 21  은평구  1873       1138    224    278    468
# 20  용산구  1624       1368    218    112    398

# %%
pop_Seoul.head()
# Out:
#          구별   구별      인구수       한국인      외국인      고령자     인구.3     인구.4  \
# 1        기간  자치구       세대         계       남자       여자        계       남자
# 2  2017.1/4   합계  4202888  10197604  5000005  5197599  9926968  4871560
# 3  2017.1/4  종로구    72654    162820    79675    83145   153589    75611
# 4  2017.1/4   중구    59481    133240    65790    67450   124312    61656
# 5  2017.1/4  용산구   106544    244203   119132   125071   229456   111167
#
#       인구.5    인구.6    인구.7    인구.8  세대당인구  65세이상고령자
# 1       여자       계      남자      여자  세대당인구  65세이상고령자
# 2  5055408  270636  128445  142191   2.36   1321458
# 3    77978    9231    4064    5167   2.11     25425
# 4    62656    8928    4134    4794   2.09     20764
# 5   118289   14747    7965    6782   2.15     36231

# %%
pop_Seoul.columns
# Out:
# Index(['구별', '구별', '인구수', '한국인', '외국인', '고령자', '인구.3', '인구.4', '인구.5', '인구.6',
#        '인구.7', '인구.8', '세대당인구', '65세이상고령자'],
#       dtype='object')

# %%
pop_Seoul.rename(columns = {pop_Seoul.columns[1] : "구별",
                            pop_Seoul.columns[2] : "인구수",
                            pop_Seoul.columns[3] : "한국인",
                            pop_Seoul.columns[4] : "외국인",
                            pop_Seoul.columns[5] : "고령자",
                            }, inplace = True)

# %%
pop_Seoul.head()
# Out:
#          구별   구별      인구수       한국인      외국인      고령자     인구.3     인구.4  \
# 1        기간  자치구       세대         계       남자       여자        계       남자
# 2  2017.1/4   합계  4202888  10197604  5000005  5197599  9926968  4871560
# 3  2017.1/4  종로구    72654    162820    79675    83145   153589    75611
# 4  2017.1/4   중구    59481    133240    65790    67450   124312    61656
# 5  2017.1/4  용산구   106544    244203   119132   125071   229456   111167
#
#       인구.5    인구.6    인구.7    인구.8  세대당인구  65세이상고령자
# 1       여자       계      남자      여자  세대당인구  65세이상고령자
# 2  5055408  270636  128445  142191   2.36   1321458
# 3    77978    9231    4064    5167   2.11     25425
# 4    62656    8928    4134    4794   2.09     20764
# 5   118289   14747    7965    6782   2.15     36231

# %%
pop_Seoul.drop([0],inplace = True)
pop_Seoul.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-5b5d78563915> in <module>()
# ----> 1 pop_Seoul.drop([0],inplace = True)
#       2 pop_Seoul.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# -> 3624                                  labels[mask])
#    3625             indexer = indexer[~mask]
# ...

# %%
pop_Seoul['구별'].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-b8f2a2369da7> in <module>()
# ----> 1 pop_Seoul['구별'].unique()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
pop_Seoul['구별'].isnull()
# Out:
#        구별     구별
# 1   False  False
# 2   False  False
# 3   False  False
# 4   False  False
# 5   False  False
# 6   False  False
# 7   False  False
# 8   False  False
# 9   False  False
# 10  False  False
# 11  False  False
# 12  False  False
# 13  False  False
# 14  False  False
# 15  False  False
# 16  False  False
# 17  False  False
# 18  False  False
# 19  False  False
# 20  False  False
# 21  False  False
# 22  False  False
# 23  False  False
# 24  False  False
# 25  False  False
# 27  False  False
# 28   True   True

# %%
pop_Seoul[pop_Seoul['구별'].isnull()]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-142821c95e62> in <module>()
# ----> 1 pop_Seoul[pop_Seoul['구별'].isnull()]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
# -> 1960             return self._getitem_frame(key)
#    1961         elif is_mi_columns:
#    1962             return self._getitem_multilevel(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_frame(self, key)
#    2034         if key.values.size and not is_bool_dtype(key.values):
#    2035             raise ValueError('Must pass DataFrame with boolean values only')
# -> 2036         return self.where(key)
#    2037
#    2038     def query(self, expr, inplace=False, **kwargs):
#
# ...

# %%
pop_Seoul.drop([26], inplace = True)
pop_Seoul
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-6d144f3f3ff9> in <module>()
# ----> 1 pop_Seoul.drop([26], inplace = True)
#       2 pop_Seoul
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# -> 3624                                  labels[mask])
#    3625             indexer = indexer[~mask]
# ...

# %%
pop_Seoul[pop_Seoul['구별'].isnull()]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-142821c95e62> in <module>()
# ----> 1 pop_Seoul[pop_Seoul['구별'].isnull()]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
# -> 1960             return self._getitem_frame(key)
#    1961         elif is_mi_columns:
#    1962             return self._getitem_multilevel(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_frame(self, key)
#    2034         if key.values.size and not is_bool_dtype(key.values):
#    2035             raise ValueError('Must pass DataFrame with boolean values only')
# -> 2036         return self.where(key)
#    2037
#    2038     def query(self, expr, inplace=False, **kwargs):
#
# ...

# %%
pop_Seoul['외국인비율'] = pop_Seoul['고령자']/pop_Seoul['인구수']*100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     657             result = expressions.evaluate(op, str_rep, x, y,
# --> 658                                           raise_on_error=True, **eval_kwargs)
#     659         except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, raise_on_error, use_numexpr, **eval_kwargs)
#     210         return _evaluate(op, op_str, a, b, raise_on_error=raise_on_error,
# --> 211                          **eval_kwargs)
#     212     return _evaluate_standard(op, op_str, a, b, raise_on_error=raise_on_error)
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, raise_on_error, truediv, reversed, **eval_kwargs)
#     121     if result is None:
# ...

# %%
pop_Seoul.sort_values(by = '인구수').head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-ed49937dc118> in <module>()
# ----> 1 pop_Seoul.sort_values(by = '인구수').head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3199
#    3200             indexer = nargsort(k, kind=kind, ascending=ascending,
# -> 3201                                na_position=na_position)
#    3202
#    3203         new_data = self._data.take(indexer,
#
# ~\Anaconda3\lib\site-packages\pandas\core\sorting.py in nargsort(items, kind, ascending, na_position)
#     245         non_nans = non_nans[::-1]
#     246         non_nan_idx = non_nan_idx[::-1]
# --> 247     indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     248     if not ascending:
#     249         indexer = indexer[::-1]
#
# ...

# %%
pop_Seoul.sort_values(by = '인구수',ascending = False).head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-5906e4a4f335> in <module>()
# ----> 1 pop_Seoul.sort_values(by = '인구수',ascending = False).head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3199
#    3200             indexer = nargsort(k, kind=kind, ascending=ascending,
# -> 3201                                na_position=na_position)
#    3202
#    3203         new_data = self._data.take(indexer,
#
# ~\Anaconda3\lib\site-packages\pandas\core\sorting.py in nargsort(items, kind, ascending, na_position)
#     245         non_nans = non_nans[::-1]
#     246         non_nan_idx = non_nan_idx[::-1]
# --> 247     indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     248     if not ascending:
#     249         indexer = indexer[::-1]
#
# ...

# %%
CCTV_seoul['최근증가율'] = (CCTV_seoul['2016년']+
                            CCTV_seoul['2015년']+
                            CCTV_seoul['2014년']
                            ) / CCTV_seoul['2013년도 이전']*100

# %%
CCTV_seoul['최근증가율']
# Out:
# 0     150.619195
# 1     166.490765
# 2     125.203252
# 3     134.793814
# 4     149.290780
# 5      53.228621
# 6      64.973730
# 7     100.000000
# 8     188.929889
# 9     246.638655
# 10     74.766355
# 11    139.338235
# 12    212.101911
# 13     48.578199
# 14     63.371266
# 15     81.780822
# 16     63.627354
# 17    104.347826
# 18     34.671731
# 19    157.979798
# 20     53.216374
# 21     85.237258
# 22    248.922414
# 23    147.699758
# 24     79.960707
# Name: 최근증가율, dtype: float64

# %%
CCTV_seoul
# Out:
#       구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율
# 0    강남구  2780       1292    430    584    932  150.619195
# 1    강동구   773        379     99    155    377  166.490765
# 2    강북구   748        369    120    138    204  125.203252
# 3    강서구   884        388    258    184     81  134.793814
# 4    관악구  1496        846    260    390    613  149.290780
# 5    광진구   707        573     78     53    174   53.228621
# 6    구로구  1561       1142    173    246    323   64.973730
# 7    금천구  1015        674     51    269    354  100.000000
# 8    노원구  1265        542     57    451    516  188.929889
# 9    도봉구   485        238    159     42    386  246.638655
# 10  동대문구  1294       1070     23    198    579   74.766355
# 11   동작구  1091        544    341    103    314  139.338235
# 12   마포구   574        314    118    169    379  212.101911
# 13  서대문구   962        844     50     68    292   48.578199
# 14   서초구  1930       1406    157    336    398   63.371266
# ...

# %%
data_result = pd.merge(CCTV_seoul, pop_Seoul, on = '구별')
data_result
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-365576cfa998> in <module>()
# ----> 1 data_result = pd.merge(CCTV_seoul, pop_Seoul, on = '구별')
#       2 data_result
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      52                          right_index=right_index, sort=sort, suffixes=suffixes,
#      53                          copy=copy, indicator=indicator)
# ---> 54     return op.get_result()
#      55
#      56
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     567                 self.left, self.right)
#     568
# --> 569         join_index, left_indexer, right_indexer = self._get_join_info()
#     570
#     571         ldata, rdata = self.left._data, self.right._data
#
# ...

# %%
del data_result['2013년도 이전']
del data_result['2014년']
del data_result['2015년']
del data_result['2016년']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-15569f7002ea> in <module>()
# ----> 1 del data_result['2013년도 이전']
#       2 del data_result['2014년']
#       3 del data_result['2015년']
#       4 del data_result['2016년']
#
# NameError: name 'data_result' is not defined

# %%
data_result.set_index('구별',inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-c2c347af9c01> in <module>()
# ----> 1 data_result.set_index('구별',inplace = True)
#
# NameError: name 'data_result' is not defined

# %%
import numpy as np

# %%
np.corrcoef(data_result['고령자비율'],data_result['소계'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-f3d7a701324a> in <module>()
# ----> 1 np.corrcoef(data_result['고령자비율'],data_result['소계'])
#
# NameError: name 'data_result' is not defined

# %%
import matplotlib as plt #보고서에 작성 / 한글을 지원하지 않는다.
# %matplotlib inline

# %%
import platform

# %%
plt.figure()
data_result['소계'].plot(kind = 'barh', grid = True,figsize=(10,10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-754d6f281b4d> in <module>()
# ----> 1 plt.figure()
#       2 data_result['소계'].plot(kind = 'barh', grid = True,figsize=(10,10))
#
# TypeError: 'module' object is not callable
